# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

## for feature slection

from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# to visualise al the columns in the dataframe
pd.pandas.set_option('display.max_columns', None)

# %%
dataset = pd.read_csv('dataset_engg.csv')

# %% [markdown]
# ## Splitting Data into test and train ds

# %%
all_features=[feature for feature in dataset.columns if feature not in ['Id','SalePrice']]

# %%
X = dataset[all_features].values
y = dataset['SalePrice'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 32)

# %% [markdown]
# ## Perform Feature Scaling

# %%
y_train = y_train.reshape(len(y_train), 1)
y_test = y_test.reshape(len(y_test), 1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_X=MinMaxScaler()
scaler_X.fit(X_train)
scaler_y=MinMaxScaler()
scaler_y.fit(y_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler_X.transform(X_train)
X_test = scaler_X.transform(X_test)
y_train = scaler_y.transform(y_train)
y_test = scaler_y.transform(y_test)

# %%
y_train = y_train.flatten()
y_test = y_test.flatten()

# %%
print(X_train.shape)
# Out:
# (1168, 82)

# %% [markdown]
# ## Perform Feature Selection

# %%
### Apply Feature Selection
# first, I specify the Lasso Regression model, and I
# select a suitable alpha (equivalent of penalty).
# The bigger the alpha the less features that will be selected.

# Then I use the selectFromModel object from sklearn, which
# will select the features which coefficients are non-zero

feature_sel_model = SelectFromModel(Lasso(alpha=0.0001, random_state=32)) # remember to set the seed, the random state in this function
feature_sel_model.fit(X_train, y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.0001, random_state=32))

# %%
# from sklearn.svm import SVR
# from sklearn.model_selection import GridSearchCV
# alpha = [i*0.0001 for i in range(1,25)]
# tuned_parameters = [{'alpha': alpha}]
# grid_search = GridSearchCV(estimator = Lasso(),
#                            param_grid = tuned_parameters,
#                            cv = 10,
#                            n_jobs = -1)
# grid_search = grid_search.fit(X_train, y_train)
# best_score = grid_search.best_score_
# best_parameters = grid_search.best_params_
# print("Best Score: {:.2f} %".format(best_score*100))
# print("Best Parameters:", best_parameters)

# %%
selected_columns = feature_sel_model.get_support()

# %%
def get_updated_array(X_train, all_features, selected_columns):
    df = pd.DataFrame(X_train,columns = all_features)
    selected_feat = df.columns[(selected_columns)]
    return df[selected_feat]

# %%
train_df_upd = get_updated_array(X_train, all_features, selected_columns)
X_train = train_df_upd.values

# %%
len(train_df_upd.columns)
# Out:
# 58

# %%
test_df_upd = get_updated_array(X_test, all_features, selected_columns)
X_test = test_df_upd.values

# %% [markdown]
# ## Save data

# %%
train_df_upd['SalePrice'] = y_train
test_df_upd['SalePrice'] = y_test

# %%
test_df_upd.head()
# Out:
#    MSSubClass  MSZoning   LotArea  LandContour  LotConfig  Neighborhood  \
# 0    0.823529      0.25  0.052965     0.333333        0.0      0.090909
# 1    0.000000      0.75  0.665913     0.333333        1.0      0.727273
# 2    0.588235      0.75  0.234455     0.333333        0.0      0.681818
# 3    0.235294      0.75  0.489284     0.333333        0.0      0.954545
# 4    0.235294      0.75  0.411848     0.333333        1.0      0.636364
#
#    Condition1  Condition2  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0         0.4         1.0         1.0     0.555556        0.875   0.272059
# 1         0.4         1.0         0.6     0.555556        0.250   0.367647
# 2         0.4         1.0         0.6     0.666667        0.500   0.000000
# 3         0.4         1.0         1.0     0.888889        0.500   0.007353
# 4         0.4         1.0         1.0     0.666667        0.625   0.051471
#
#    YearRemodAdd  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  \
# 0      0.033333        0.0       0.0          0.6          0.5        0.50
# 1      0.533333        1.0       0.0          0.2          0.6        0.75
# 2      0.000000        1.0       0.0          1.0          1.0        0.50
# 3      0.000000        1.0       0.0          1.0          1.0        1.00
# 4      0.116667        0.0       0.0          1.0          1.0        0.50
#
#    ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  BsmtExposure  \
# 0   0.333333        1.0         0.5      0.50      0.75          0.25
# 1   0.666667        1.0         1.0      0.50      0.75          0.25
# 2   0.666667        1.0         1.0      0.75      0.75          0.75
# 3   1.000000        1.0         1.0      1.00      0.75          1.00
# 4   0.666667        1.0         1.0      0.75      0.75          0.25
#
#    BsmtFinType1  BsmtFinSF1  BsmtFinType2  BsmtUnfSF  Heating  HeatingQC  \
# 0      0.666667    0.028703      0.833333   0.137414      1.0       0.75
# 1      0.166667    0.215982      0.833333   0.349315      1.0       0.50
# 2      1.000000    0.189582      0.833333   0.122432      1.0       1.00
# 3      0.833333    0.000000      0.833333   0.742295      1.0       1.00
# 4      1.000000    0.085578      0.833333   0.196062      1.0       1.00
#
#    CentralAir  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# 0         1.0  0.103018  0.244068           0.0   0.317888      0.000000
# 1         1.0  0.753982  0.000000           0.0   0.683867      0.333333
# 2         1.0  0.550091  0.000000           0.0   0.481655      0.333333
# 3         1.0  0.607283  0.526877           0.0   0.728930      0.000000
# 4         1.0  0.366135  0.430024           0.0   0.559246      0.333333
#
#    FullBath  HalfBath  KitchenAbvGr  KitchenQual  Functional  Fireplaces  \
# 0  0.333333       0.5      0.333333     0.666667         1.0    0.000000
# 1  1.000000       0.0      0.666667     0.333333         0.0    0.666667
# 2  0.666667       0.0      0.333333     0.666667         1.0    0.333333
# 3  1.000000       0.5      0.333333     1.000000         1.0    0.333333
# 4  0.666667       0.5      0.333333     0.666667         1.0    0.333333
#
#    FireplaceQu  GarageYrBlt  GarageFinish  GarageCars  GarageQual  WoodDeckSF  \
# 0          0.2     0.345794      0.333333        0.25    0.666667    0.291715
# 1          0.6     0.299065      0.666667        0.50    0.666667    0.000000
# 2          0.8     0.000000      1.000000        0.75    0.666667    0.187865
# 3          0.8     0.000000      0.666667        0.75    0.666667    0.060677
# 4          0.6     0.065421      0.666667        0.50    0.666667    0.224037
#
#    OpenPorchSF  EnclosedPorch  ScreenPorch  PoolQC  MiscFeature  YrSold  \
# 0     0.000000       0.000000          0.0     0.0          1.0    0.75
# 1     0.000000       0.362319          0.0     0.0          1.0    0.25
# 2     0.036563       0.000000          0.0     0.0          1.0    0.00
# 3     0.310786       0.000000          0.4     0.0          1.0    0.75
# 4     0.071298       0.000000          0.0     0.0          1.0    1.00
#
#    SaleType  SaleCondition  GarageYrBltnan  SalePrice
# 0  0.666667           0.75             0.0   0.393953
# 1  0.666667           0.25             0.0   0.567257
# 2  1.000000           1.00             0.0   0.634602
# 3  1.000000           1.00             0.0   0.915545
# 4  0.666667           0.75             0.0   0.621666

# %%
train_df_upd.to_csv('train_df_upd.csv',index=False)
test_df_upd.to_csv('test_df_upd.csv',index=False)
